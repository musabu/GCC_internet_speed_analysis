# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb
import datetime as dt
import warnings; warnings.simplefilter('ignore')
# %matplotlib inline
plt.rcParams['figure.figsize'] = (15, 7)
palette = sb.color_palette("viridis", 4)
#sb.set(style="whitegrid")                                                 
paper_rc = {'lines.linewidth': 2, 'lines.markersize': 8}                  
sb.set_context("paper", rc = paper_rc)    
#sb.set_palette("colorblind")

#marker = ['o', 'x', '^', '+', '*', '8', 's', 'p', 'D', 'V']

# %% [markdown]
# # City by City Analysis

# %% [markdown]
# ## Riyadh - Download

# %%
df1 = pd.read_csv(r'riyadh\riyadh_download_may22_2019.csv', parse_dates=['date'], index_col='date')
df2 = pd.read_csv(r'riyadh\riyadh_download_may22_2020.csv', parse_dates=['date'], index_col='date')
df3 = pd.read_csv(r'riyadh\riyadh_download_may22_2021.csv', parse_dates=['date'], index_col='date')
dfs = [df1, df2, df3]
df = pd.concat(dfs)
#df = pd.read_csv(r'riyadh\riyadh.csv', parse_dates=['date'], index_col='date')
#mainStats = df.describe()
#noOfRecordsPerMonth = df.groupby(pd.Grouper(freq='M'))['MeanThroughputMbps'].count() # Number of records collected for each month
dfRiyadh = df.resample('M').agg({'MeanThroughputMbps':'mean'}).rename(columns={"MeanThroughputMbps":"Throughput_Riyadh"})
dfRiyadh['month'] = pd.to_datetime(dfRiyadh.index).month
dfRiyadh['year'] = pd.to_datetime(dfRiyadh.index).year
#print("Number of Records per Month")
#print(noOfRecordsPerMonth)
#print("\nMain Statistics")
#print(mainStats)
#print("\nMean of Records collected per month")
#print(noOfRecordsPerMonth.mean())
#print("\nMean Mbps Per Month")
#print(dfRiyadh)
dfRiyadh
# Out:
#             Throughput_Riyadh  month  year
# date
# 2019-05-31           8.550000      5  2019
# 2019-06-30           9.200595      6  2019
# 2019-07-31           6.935082      7  2019
# 2019-08-31          10.852727      8  2019
# 2019-09-30          11.308995      9  2019
# 2019-10-31          11.330495     10  2019
# 2019-11-30          13.663377     11  2019
# 2019-12-31          17.734871     12  2019
# 2020-01-31          16.836022      1  2020
# 2020-02-29          17.827760      2  2020
# 2020-03-31          14.907954      3  2020
# 2020-04-30          15.397471      4  2020
# 2020-05-31          17.787167      5  2020
# 2020-06-30          17.920942      6  2020
# 2020-07-31          16.991836      7  2020
# 2020-08-31          17.921334      8  2020
# 2020-09-30          16.907168      9  2020
# 2020-10-31          18.980960     10  2020
# 2020-11-30          20.427681     11  2020
# 2020-12-31          22.061577     12  2020
# 2021-01-31          19.950771      1  2021
# 2021-02-28          19.846452      2  2021
# 2021-03-31          19.232558      3  2021
# 2021-04-30          22.883160      4  2021
# 2021-05-31          19.856979      5  2021
# 2021-06-30          20.279521      6  2021
# 2021-07-31          23.632071      7  2021
# 2021-08-31          22.240598      8  2021
# 2021-09-30          21.163781      9  2021
# 2021-10-31          21.462960     10  2021
# 2021-11-30          21.791974     11  2021
# 2021-12-31          23.213104     12  2021
# 2022-01-31          24.101402      1  2022
# 2022-02-28          24.238165      2  2022
# 2022-03-31          28.249403      3  2022
# 2022-04-30          29.925470      4  2022

# %% [markdown]
# ## Riyadh Upload

# %%
df1 = pd.read_csv(r'riyadh\riyadh_upload_may22_2019.csv', parse_dates=['date'], index_col='date')
df2 = pd.read_csv(r'riyadh\riyadh_upload_may22_2020.csv', parse_dates=['date'], index_col='date')
df3 = pd.read_csv(r'riyadh\riyadh_upload_may22_2021.csv', parse_dates=['date'], index_col='date')
dfs = [df1, df2, df3]
df = pd.concat(dfs)

#df = pd.read_csv(r'riyadh\riyadh_upload.csv', parse_dates=['date'], index_col='date')
#mainStats = df.describe()
#noOfRecordsPerMonth = df.groupby(pd.Grouper(freq='M'))['MeanThroughputMbps'].count() # Number of records collected for each month
dfRiyadh_upload = df.resample('M').agg({'MeanThroughputMbps':'mean'}).rename(columns={"MeanThroughputMbps":"Throughput_Riyadh"})
dfRiyadh_upload['month'] = pd.to_datetime(dfRiyadh_upload.index).month
dfRiyadh_upload['year'] = pd.to_datetime(dfRiyadh_upload.index).year
#print("Number of Records per Month")
#print(noOfRecordsPerMonth)
#print("\nMain Statistics")
#print(mainStats)
#print("\nMean of Records collected per month")
#print(noOfRecordsPerMonth.mean())
#print("\nMean Mbps Per Month")
#print(dfRiyadh_upload)

dfRiyadh_upload
# Out:
#             Throughput_Riyadh  month  year
# date
# 2019-05-31           6.954969      5  2019
# 2019-06-30           7.200043      6  2019
# 2019-07-31           5.117362      7  2019
# 2019-08-31           7.846263      8  2019
# 2019-09-30           8.433791      9  2019
# 2019-10-31           8.730714     10  2019
# 2019-11-30          10.240765     11  2019
# 2019-12-31          10.916488     12  2019
# 2020-01-31          11.015988      1  2020
# 2020-02-29          11.411877      2  2020
# 2020-03-31           9.820667      3  2020
# 2020-04-30           9.882204      4  2020
# 2020-05-31          10.682267      5  2020
# 2020-06-30          12.099548      6  2020
# 2020-07-31          11.274650      7  2020
# 2020-08-31          10.386020      8  2020
# 2020-09-30          10.652541      9  2020
# 2020-10-31          12.346585     10  2020
# 2020-11-30          11.891255     11  2020
# 2020-12-31          12.835981     12  2020
# 2021-01-31          13.811362      1  2021
# 2021-02-28          12.302001      2  2021
# 2021-03-31          11.540954      3  2021
# 2021-04-30          14.740590      4  2021
# 2021-05-31          13.737980      5  2021
# 2021-06-30          11.776195      6  2021
# 2021-07-31          15.339737      7  2021
# 2021-08-31          14.457650      8  2021
# 2021-09-30          14.426602      9  2021
# 2021-10-31          14.788827     10  2021
# 2021-11-30          15.381159     11  2021
# 2021-12-31          16.067404     12  2021
# 2022-01-31          15.947681      1  2022
# 2022-02-28          15.960785      2  2022
# 2022-03-31          16.349318      3  2022
# 2022-04-30          17.712403      4  2022

# %% [markdown]
# ## Riyadh Plots

# %%
fig, ax = plt.subplots(1,2)

sb.lineplot(x='month',y='Throughput_Riyadh',data=dfRiyadh, hue = 'year', 
            style='year', markers=True, palette=palette, size='year', 
            legend=False, ax = ax[0]) # for download

sb.lineplot(x='month',y='Throughput_Riyadh',data=dfRiyadh_upload, hue = 'year', 
            style='year', markers=True, palette=palette, size='year', 
            legend=False, ax = ax[1]) # for upload

ax[0].tick_params(axis = 'both', which = 'major', labelsize = 15)
ax[0].set_xlabel('Months of the Year', fontdict={'fontsize': 14}, labelpad = 15)
ax[0].set_ylabel('Throughput (Mbps)', fontdict={'fontsize': 14}, labelpad = 15)
ax[0].set_title('Download', fontdict={'fontsize': 20})

ax[1].tick_params(axis = 'both', which = 'major', labelsize = 15)
ax[1].set_xlabel('Months of the Year', fontdict={'fontsize': 14}, labelpad = 15)
ax[1].set_ylabel('Throughput (Mbps)', fontdict={'fontsize': 14}, labelpad = 15)
ax[1].set_title('Upload', fontdict={'fontsize': 20})
ax[1].yaxis.tick_right()
ax[1].yaxis.set_label_position('right')

plt.margins(0.03)
ax[0].legend(labels=['2019','2020', '2021', '2022'], prop={'size': 14}, bbox_to_anchor=(1.2, 1.3))
plt.savefig('figures/riyadhthru.pdf', bbox_inches='tight')

# %% [markdown]
# ## Dubai - Download

# %%
#Dubai - Import Data
df1 = pd.read_csv(r'dubai\dubai_download_may22_2019.csv', parse_dates=['date'], index_col='date')
df2 = pd.read_csv(r'dubai\dubai_download_may22_2020.csv', parse_dates=['date'], index_col='date')
df3 = pd.read_csv(r'dubai\dubai_download_may22_2021.csv', parse_dates=['date'], index_col='date')
dfs = [df1, df2, df3]
df = pd.concat(dfs)

#mainStats = df.describe()
#noOfRecordsPerMonth = df.groupby(pd.Grouper(freq='M'))['MeanThroughputMbps'].count() # Number of records collected for each month
dfDubai = df.resample('M').agg({'MeanThroughputMbps':'mean'}).rename(columns={"MeanThroughputMbps":"Throughput_Dubai"})
dfDubai['month'] = pd.to_datetime(dfDubai.index).month
dfDubai['year'] = pd.to_datetime(dfDubai.index).year
#print("Number of Records per Month")
#print(noOfRecordsPerMonth)
#print("\nMain Statistics")
#print(mainStats)
#print("\nMean of Records collected per month")
#print(noOfRecordsPerMonth.mean())
#print("\nMean Mbps Per Month")
dfDubai


#mask = (df['birth_date'] > start_date) & (df['birth_date'] <= end_date)
#dfDubai
# Out:
#             Throughput_Dubai  month  year
# date
# 2019-05-31         12.021286      5  2019
# 2019-06-30         14.334405      6  2019
# 2019-07-31         13.185197      7  2019
# 2019-08-31         10.594795      8  2019
# 2019-09-30         10.108736      9  2019
# 2019-10-31         13.166572     10  2019
# 2019-11-30         37.243043     11  2019
# 2019-12-31         43.031984     12  2019
# 2020-01-31         50.535517      1  2020
# 2020-02-29         43.800658      2  2020
# 2020-03-31         25.935159      3  2020
# 2020-04-30         33.674664      4  2020
# 2020-05-31         37.977888      5  2020
# 2020-06-30         40.004711      6  2020
# 2020-07-31         38.291011      7  2020
# 2020-08-31         35.421669      8  2020
# 2020-09-30         34.914503      9  2020
# 2020-10-31         34.729031     10  2020
# 2020-11-30         33.336914     11  2020
# 2020-12-31         36.976850     12  2020
# 2021-01-31         35.146929      1  2021
# 2021-02-28         32.314466      2  2021
# 2021-03-31         32.317868      3  2021
# 2021-04-30         31.418439      4  2021
# 2021-05-31         31.299318      5  2021
# 2021-06-30         23.570002      6  2021
# 2021-07-31         30.760233      7  2021
# 2021-08-31         21.477808      8  2021
# 2021-09-30         23.231090      9  2021
# 2021-10-31         27.364553     10  2021
# 2021-11-30         30.997761     11  2021
# 2021-12-31         33.469855     12  2021
# 2022-01-31         24.576056      1  2022
# 2022-02-28         27.192727      2  2022
# 2022-03-31         26.789707      3  2022
# 2022-04-30         28.037629      4  2022

# %% [markdown]
# ## Dubai - Upload

# %%
df1 = pd.read_csv(r'dubai\dubai_upload_may22_2019.csv', parse_dates=['date'], index_col='date')
df2 = pd.read_csv(r'dubai\dubai_upload_may22_2020.csv', parse_dates=['date'], index_col='date')
df3 = pd.read_csv(r'dubai\dubai_upload_may22_2021.csv', parse_dates=['date'], index_col='date')
dfs = [df1, df2, df3]
df = pd.concat(dfs)

#mainStats = df.describe()
#noOfRecordsPerMonth = df.groupby(pd.Grouper(freq='M'))['MeanThroughputMbps'].count() # Number of records collected for each month
dfDubai_upload = df.resample('M').agg({'MeanThroughputMbps':'mean'}).rename(columns={"MeanThroughputMbps":"Throughput_Dubai"})
dfDubai_upload['month'] = pd.to_datetime(dfDubai_upload.index).month
dfDubai_upload['year'] = pd.to_datetime(dfDubai_upload.index).year
#print("Number of Records per Month")
#print(noOfRecordsPerMonth)
#print("\nMain Statistics")
#print(mainStats)
#print("\nMean of Records collected per month")
#print(noOfRecordsPerMonth.mean())
#print("\nMean Mbps Per Month")
#print(dfDubai)


#mask = (df['birth_date'] > start_date) & (df['birth_date'] <= end_date)
dfDubai_upload
# Out:
#             Throughput_Dubai  month  year
# date
# 2019-05-31          7.105324      5  2019
# 2019-06-30          8.679231      6  2019
# 2019-07-31          9.359389      7  2019
# 2019-08-31          8.502303      8  2019
# 2019-09-30          8.756039      9  2019
# 2019-10-31         10.030021     10  2019
# 2019-11-30         11.931191     11  2019
# 2019-12-31         13.163269     12  2019
# 2020-01-31         14.096542      1  2020
# 2020-02-29         12.212917      2  2020
# 2020-03-31         13.191218      3  2020
# 2020-04-30         15.559615      4  2020
# 2020-05-31         16.310244      5  2020
# 2020-06-30         34.807481      6  2020
# 2020-07-31         32.962583      7  2020
# 2020-08-31         28.882775      8  2020
# 2020-09-30         27.868677      9  2020
# 2020-10-31         27.604779     10  2020
# 2020-11-30         28.665888     11  2020
# 2020-12-31         33.886522     12  2020
# 2021-01-31         29.316530      1  2021
# 2021-02-28         30.582232      2  2021
# 2021-03-31         28.784450      3  2021
# 2021-04-30         29.903875      4  2021
# 2021-05-31         35.251893      5  2021
# 2021-06-30         29.089386      6  2021
# 2021-07-31         36.353511      7  2021
# 2021-08-31         30.273760      8  2021
# 2021-09-30         29.989423      9  2021
# 2021-10-31         30.679051     10  2021
# 2021-11-30         37.459452     11  2021
# 2021-12-31         41.724462     12  2021
# 2022-01-31         30.434557      1  2022
# 2022-02-28         27.198176      2  2022
# 2022-03-31         30.282406      3  2022
# 2022-04-30         33.136233      4  2022

# %% [markdown]
# ## Dubai Plot

# %%
#Dubai plot

fig, ax = plt.subplots(1,2)

sb.lineplot(x='month',y='Throughput_Dubai',data=dfDubai, hue = 'year', 
            style='year', markers=True, palette=palette, size='year', 
            legend=False, ax = ax[0]) # for download

sb.lineplot(x='month',y='Throughput_Dubai',data=dfDubai_upload, hue = 'year', 
            style='year', markers=True, palette=palette, size='year', 
            legend=False, ax = ax[1]) # for upload

ax[0].tick_params(axis = 'both', which = 'major', labelsize = 15)
ax[0].set_xlabel('Months of the Year', fontdict={'fontsize': 14}, labelpad = 15)
ax[0].set_ylabel('Throughput (Mbps)', fontdict={'fontsize': 14}, labelpad = 15)
ax[0].set_title('Download', fontdict={'fontsize': 20})

ax[1].tick_params(axis = 'both', which = 'major', labelsize = 15)
ax[1].set_xlabel('Months of the Year', fontdict={'fontsize': 14}, labelpad = 15)
ax[1].set_ylabel('Throughput (Mbps)', fontdict={'fontsize': 14}, labelpad = 15)
ax[1].set_title('Upload', fontdict={'fontsize': 20})
ax[1].yaxis.tick_right()
ax[1].yaxis.set_label_position('right')

plt.margins(0.03)
ax[0].legend(labels=['2019','2020', '2021', '2022'], prop={'size': 14}, bbox_to_anchor=(1.2, 1.3))
plt.savefig('figures/dubaithru.pdf', bbox_inches='tight')

# %% [markdown]
# ## Kuwait - Download

# %%
#Kuwait City - Import Data
df = pd.read_csv(r'kuwait_city\kuwaitcity_download_may22.csv', parse_dates=['date'], index_col='date')

#mainStats = df.describe()
#noOfRecordsPerMonth = df.groupby(pd.Grouper(freq='M'))['MeanThroughputMbps'].count() # Number of records collected for each month
dfKuwait = df.resample('M').agg({'MeanThroughputMbps':'mean'}).rename(columns={"MeanThroughputMbps":"Throughput_Kuwait"})
dfKuwait['month'] = pd.to_datetime(dfKuwait.index).month
dfKuwait['year'] = pd.to_datetime(dfKuwait.index).year
#print("Number of Records per Month")
#print(noOfRecordsPerMonth)
#print("\nMain Statistics")
#print(mainStats)
#print("\nMean of Records collected per month")
#print(noOfRecordsPerMonth.mean())
#print("\nMean Mbps Per Month")
#print(dfDubai)


#mask = (df['birth_date'] > start_date) & (df['birth_date'] <= end_date)
dfKuwait
# Out:
#             Throughput_Kuwait  month  year
# date
# 2019-05-31           7.977520      5  2019
# 2019-06-30           7.725719      6  2019
# 2019-07-31           9.007722      7  2019
# 2019-08-31          10.007406      8  2019
# 2019-09-30           8.468122      9  2019
# 2019-10-31           8.134635     10  2019
# 2019-11-30          13.125383     11  2019
# 2019-12-31          15.190446     12  2019
# 2020-01-31          13.580507      1  2020
# 2020-02-29          15.153355      2  2020
# 2020-03-31          12.335326      3  2020
# 2020-04-30          14.038119      4  2020
# 2020-05-31          14.648899      5  2020
# 2020-06-30          15.282676      6  2020
# 2020-07-31          15.955960      7  2020
# 2020-08-31          18.517495      8  2020
# 2020-09-30          18.726344      9  2020
# 2020-10-31          19.560530     10  2020
# 2020-11-30          17.256931     11  2020
# 2020-12-31          17.445714     12  2020
# 2021-01-31          17.635352      1  2021
# 2021-02-28          18.203869      2  2021
# 2021-03-31          15.844525      3  2021
# 2021-04-30          19.433452      4  2021
# 2021-05-31          20.039121      5  2021
# 2021-06-30          23.470246      6  2021
# 2021-07-31          26.797450      7  2021
# 2021-08-31          25.090554      8  2021
# 2021-09-30          23.717219      9  2021
# 2021-10-31          29.382171     10  2021
# 2021-11-30          32.895429     11  2021
# 2021-12-31          32.837621     12  2021
# 2022-01-31          27.941878      1  2022
# 2022-02-28          32.443426      2  2022
# 2022-03-31          33.872584      3  2022
# 2022-04-30          35.358825      4  2022

# %% [markdown]
# ## Kuwait - Upload

# %%
df = pd.read_csv(r'kuwait_city\kuwaitcity_upload_may22.csv', parse_dates=['date'], index_col='date')

#mainStats = df.describe()
#noOfRecordsPerMonth = df.groupby(pd.Grouper(freq='M'))['MeanThroughputMbps'].count() # Number of records collected for each month
dfKuwait_upload = df.resample('M').agg({'MeanThroughputMbps':'mean'}).rename(columns={"MeanThroughputMbps":"Throughput_Kuwait"})
dfKuwait_upload['month'] = pd.to_datetime(dfKuwait_upload.index).month
dfKuwait_upload['year'] = pd.to_datetime(dfKuwait_upload.index).year
#print("Number of Records per Month")
#print(noOfRecordsPerMonth)
#print("\nMain Statistics")
#print(mainStats)
#print("\nMean of Records collected per month")
#print(noOfRecordsPerMonth.mean())
#print("\nMean Mbps Per Month")
#print(dfDubai)


#mask = (df['birth_date'] > start_date) & (df['birth_date'] <= end_date)
dfKuwait_upload
# Out:
#             Throughput_Kuwait  month  year
# date
# 2019-05-31           9.284054      5  2019
# 2019-06-30           9.022844      6  2019
# 2019-07-31           8.024528      7  2019
# 2019-08-31          12.672600      8  2019
# 2019-09-30          11.785689      9  2019
# 2019-10-31          10.492060     10  2019
# 2019-11-30          13.909336     11  2019
# 2019-12-31          15.411261     12  2019
# 2020-01-31          14.542837      1  2020
# 2020-02-29          15.076931      2  2020
# 2020-03-31          12.358167      3  2020
# 2020-04-30          12.100949      4  2020
# 2020-05-31          13.504008      5  2020
# 2020-06-30          13.406020      6  2020
# 2020-07-31          13.815224      7  2020
# 2020-08-31          12.884945      8  2020
# 2020-09-30          13.952126      9  2020
# 2020-10-31          15.417627     10  2020
# 2020-11-30          14.585919     11  2020
# 2020-12-31          13.152868     12  2020
# 2021-01-31          14.249307      1  2021
# 2021-02-28          15.464939      2  2021
# 2021-03-31          15.555583      3  2021
# 2021-04-30          16.245826      4  2021
# 2021-05-31          18.018583      5  2021
# 2021-06-30          18.083493      6  2021
# 2021-07-31          18.205532      7  2021
# 2021-08-31          17.165073      8  2021
# 2021-09-30          14.087889      9  2021
# 2021-10-31          17.282679     10  2021
# 2021-11-30          18.101363     11  2021
# 2021-12-31          16.067200     12  2021
# 2022-01-31          16.658189      1  2022
# 2022-02-28          18.165402      2  2022
# 2022-03-31          19.694390      3  2022
# 2022-04-30          17.921296      4  2022

# %% [markdown]
# ## Kuwait Plot

# %%
#Kuwait City plot
fig, ax = plt.subplots(1,2)

sb.lineplot(x='month',y='Throughput_Kuwait',data=dfKuwait, hue = 'year', 
            style='year', markers=True, palette=palette, size='year', 
            legend=False, ax = ax[0]) # for download

sb.lineplot(x='month',y='Throughput_Kuwait',data=dfKuwait_upload, hue = 'year', 
            style='year', markers=True, palette=palette, size='year', 
            legend=False, ax = ax[1]) # for upload

ax[0].tick_params(axis = 'both', which = 'major', labelsize = 15)
ax[0].set_xlabel('Months of the Year', fontdict={'fontsize': 14}, labelpad = 15)
ax[0].set_ylabel('Throughput (Mbps)', fontdict={'fontsize': 14}, labelpad = 15)
ax[0].set_title('Download', fontdict={'fontsize': 20})

ax[1].tick_params(axis = 'both', which = 'major', labelsize = 15)
ax[1].set_xlabel('Months of the Year', fontdict={'fontsize': 14}, labelpad = 15)
ax[1].set_ylabel('Throughput (Mbps)', fontdict={'fontsize': 14}, labelpad = 15)
ax[1].set_title('Upload', fontdict={'fontsize': 20})
ax[1].yaxis.tick_right()
ax[1].yaxis.set_label_position('right')

plt.margins(0.03)
ax[0].legend(labels=['2019','2020', '2021', '2022'], prop={'size': 14}, bbox_to_anchor=(1.2, 1.3))
plt.savefig('figures/kuwaitthru.pdf', bbox_inches='tight')

# %% [markdown]
# ## Doha - Download

# %%
#Doha - Import Data
df = pd.read_csv(r'doha\doha_download_may22.csv', parse_dates=['date'], index_col='date')

#mainStats = df.describe()
#noOfRecordsPerMonth = df.groupby(pd.Grouper(freq='M'))['MeanThroughputMbps'].count() # Number of records collected for each month
dfDoha = df.resample('M').agg({'MeanThroughputMbps':'mean'}).rename(columns={"MeanThroughputMbps":"Throughput_Doha"})
dfDoha['month'] = pd.to_datetime(dfDoha.index).month
dfDoha['year'] = pd.to_datetime(dfDoha.index).year
#print("Number of Records per Month")
#print(noOfRecordsPerMonth)
#print("\nMain Statistics")
#print(mainStats)
#print("\nMean of Records collected per month")
#print(noOfRecordsPerMonth.mean())
#print("\nMean Mbps Per Month")
#print(dfDubai)


#mask = (df['birth_date'] > start_date) & (df['birth_date'] <= end_date)
dfDoha
# Out:
#             Throughput_Doha  month  year
# date
# 2019-05-31        14.848683      5  2019
# 2019-06-30        16.190687      6  2019
# 2019-07-31        14.185931      7  2019
# 2019-08-31        14.872646      8  2019
# 2019-09-30        11.886063      9  2019
# 2019-10-31        14.784052     10  2019
# 2019-11-30        31.558462     11  2019
# 2019-12-31        27.976386     12  2019
# 2020-01-31        27.092141      1  2020
# 2020-02-29        34.776719      2  2020
# 2020-03-31        26.397149      3  2020
# 2020-04-30        28.234222      4  2020
# 2020-05-31        31.331990      5  2020
# 2020-06-30        28.900934      6  2020
# 2020-07-31        26.107042      7  2020
# 2020-08-31        24.270592      8  2020
# 2020-09-30        23.199229      9  2020
# 2020-10-31        22.888351     10  2020
# 2020-11-30        23.932701     11  2020
# 2020-12-31        23.535158     12  2020
# 2021-01-31        27.964575      1  2021
# 2021-02-28        24.313623      2  2021
# 2021-03-31        22.835318      3  2021
# 2021-04-30        23.715971      4  2021
# 2021-05-31        26.105590      5  2021
# 2021-06-30        25.247151      6  2021
# 2021-07-31        26.756933      7  2021
# 2021-08-31        25.092012      8  2021
# 2021-09-30        24.555494      9  2021
# 2021-10-31        25.467560     10  2021
# 2021-11-30        23.981709     11  2021
# 2021-12-31        27.628952     12  2021
# 2022-01-31        23.783530      1  2022
# 2022-02-28        29.405681      2  2022
# 2022-03-31        25.629402      3  2022
# 2022-04-30        25.123882      4  2022

# %% [markdown]
# ## Doha - Upload

# %%
df = pd.read_csv(r'doha\doha_upload_may22.csv', parse_dates=['date'], index_col='date')

#mainStats = df.describe()
#noOfRecordsPerMonth = df.groupby(pd.Grouper(freq='M'))['MeanThroughputMbps'].count() # Number of records collected for each month
dfDoha_upload = df.resample('M').agg({'MeanThroughputMbps':'mean'}).rename(columns={"MeanThroughputMbps":"Throughput_Doha"})
dfDoha_upload['month'] = pd.to_datetime(dfDoha_upload.index).month
dfDoha_upload['year'] = pd.to_datetime(dfDoha_upload.index).year
#print("Number of Records per Month")
#print(noOfRecordsPerMonth)
#print("\nMain Statistics")
#print(mainStats)
#print("\nMean of Records collected per month")
#print(noOfRecordsPerMonth.mean())
#print("\nMean Mbps Per Month")
#print(dfDubai)


#mask = (df['birth_date'] > start_date) & (df['birth_date'] <= end_date)
dfDoha_upload
# Out:
#             Throughput_Doha  month  year
# date
# 2019-05-31        14.257121      5  2019
# 2019-06-30        17.005862      6  2019
# 2019-07-31        16.625192      7  2019
# 2019-08-31        17.978229      8  2019
# 2019-09-30        17.221592      9  2019
# 2019-10-31        17.160883     10  2019
# 2019-11-30        27.944629     11  2019
# 2019-12-31        27.025784     12  2019
# 2020-01-31        25.949907      1  2020
# 2020-02-29        27.709209      2  2020
# 2020-03-31        23.283584      3  2020
# 2020-04-30        27.292703      4  2020
# 2020-05-31        32.203608      5  2020
# 2020-06-30        26.683152      6  2020
# 2020-07-31        26.398292      7  2020
# 2020-08-31        23.615536      8  2020
# 2020-09-30        17.566183      9  2020
# 2020-10-31        20.222823     10  2020
# 2020-11-30        26.856473     11  2020
# 2020-12-31        24.128587     12  2020
# 2021-01-31        27.583851      1  2021
# 2021-02-28        26.464316      2  2021
# 2021-03-31        25.203483      3  2021
# 2021-04-30        24.714985      4  2021
# 2021-05-31        27.024462      5  2021
# 2021-06-30        25.573993      6  2021
# 2021-07-31        28.133990      7  2021
# 2021-08-31        25.329551      8  2021
# 2021-09-30        27.485653      9  2021
# 2021-10-31        27.477152     10  2021
# 2021-11-30        28.085223     11  2021
# 2021-12-31        31.554002     12  2021
# 2022-01-31        28.658734      1  2022
# 2022-02-28        29.375847      2  2022
# 2022-03-31        28.566018      3  2022
# 2022-04-30        25.508652      4  2022

# %% [markdown]
# ## Doha Plot

# %%
#Doha plot
fig, ax = plt.subplots(1,2)

sb.lineplot(x='month',y='Throughput_Doha',data=dfDoha, hue = 'year', 
            style='year', markers=True, palette=palette, size='year', 
            legend=False, ax = ax[0]) # for download

sb.lineplot(x='month',y='Throughput_Doha',data=dfDoha_upload, hue = 'year', 
            style='year', markers=True, palette=palette, size='year', 
            legend=False, ax = ax[1]) # for upload

ax[0].tick_params(axis = 'both', which = 'major', labelsize = 15)
ax[0].set_xlabel('Months of the Year', fontdict={'fontsize': 14}, labelpad = 15)
ax[0].set_ylabel('Throughput (Mbps)', fontdict={'fontsize': 14}, labelpad = 15)
ax[0].set_title('Download', fontdict={'fontsize': 20})

ax[1].tick_params(axis = 'both', which = 'major', labelsize = 15)
ax[1].set_xlabel('Months of the Year', fontdict={'fontsize': 14}, labelpad = 15)
ax[1].set_ylabel('Throughput (Mbps)', fontdict={'fontsize': 14}, labelpad = 15)
ax[1].set_title('Upload', fontdict={'fontsize': 20})
ax[1].yaxis.tick_right()
ax[1].yaxis.set_label_position('right')

plt.margins(0.03)
ax[0].legend(labels=['2019','2020', '2021', '2022'], prop={'size': 14}, bbox_to_anchor=(1.2, 1.3))
plt.savefig('figures/dohathru.pdf', bbox_inches='tight')

# %% [markdown]
# ## Muscat - Download

# %%
#Muscat - Import Data
df = pd.read_csv(r'muscat\muscat_download_may22.csv', parse_dates=['date'], index_col='date')

#mainStats = df.describe()
#noOfRecordsPerMonth = df.groupby(pd.Grouper(freq='M'))['MeanThroughputMbps'].count() # Number of records collected for each month
dfMuscat = df.resample('M').agg({'MeanThroughputMbps':'mean'}).rename(columns={"MeanThroughputMbps":"Throughput_Muscat"})
dfMuscat['month'] = pd.to_datetime(dfMuscat.index).month
dfMuscat['year'] = pd.to_datetime(dfMuscat.index).year
#print("Number of Records per Month")
#print(noOfRecordsPerMonth)
#print("\nMain Statistics")
#print(mainStats)
#print("\nMean of Records collected per month")
#print(noOfRecordsPerMonth.mean())
#print("\nMean Mbps Per Month")
#print(dfDubai)


#mask = (df['birth_date'] > start_date) & (df['birth_date'] <= end_date)
dfMuscat
# Out:
#             Throughput_Muscat  month  year
# date
# 2019-05-31           6.046910      5  2019
# 2019-06-30           7.133383      6  2019
# 2019-07-31           5.100332      7  2019
# 2019-08-31           6.019265      8  2019
# 2019-09-30           6.621583      9  2019
# 2019-10-31           6.387797     10  2019
# 2019-11-30          11.536339     11  2019
# 2019-12-31          17.306887     12  2019
# 2020-01-31          17.239458      1  2020
# 2020-02-29          13.314410      2  2020
# 2020-03-31          10.789272      3  2020
# 2020-04-30          11.956239      4  2020
# 2020-05-31          21.026825      5  2020
# 2020-06-30          18.968774      6  2020
# 2020-07-31          18.946551      7  2020
# 2020-08-31          16.679176      8  2020
# 2020-09-30          18.946493      9  2020
# 2020-10-31          17.219793     10  2020
# 2020-11-30          16.606540     11  2020
# 2020-12-31          17.799277     12  2020
# 2021-01-31          20.607113      1  2021
# 2021-02-28          17.171986      2  2021
# 2021-03-31          16.246620      3  2021
# 2021-04-30          16.269061      4  2021
# 2021-05-31          15.872704      5  2021
# 2021-06-30          15.665547      6  2021
# 2021-07-31          17.662458      7  2021
# 2021-08-31          16.060993      8  2021
# 2021-09-30          19.626289      9  2021
# 2021-10-31          15.279808     10  2021
# 2021-11-30          17.291968     11  2021
# 2021-12-31          17.644940     12  2021
# 2022-01-31          16.256637      1  2022
# 2022-02-28          16.805765      2  2022
# 2022-03-31          16.770394      3  2022
# 2022-04-30          19.400996      4  2022

# %% [markdown]
# ## Muscat - Upload

# %%
df = pd.read_csv(r'muscat\muscat_upload_may22.csv', parse_dates=['date'], index_col='date')

#mainStats = df.describe()
#noOfRecordsPerMonth = df.groupby(pd.Grouper(freq='M'))['MeanThroughputMbps'].count() # Number of records collected for each month
dfMuscat_upload = df.resample('M').agg({'MeanThroughputMbps':'mean'}).rename(columns={"MeanThroughputMbps":"Throughput_Muscat"})
dfMuscat_upload['month'] = pd.to_datetime(dfMuscat_upload.index).month
dfMuscat_upload['year'] = pd.to_datetime(dfMuscat_upload.index).year
#print("Number of Records per Month")
#print(noOfRecordsPerMonth)
#print("\nMain Statistics")
#print(mainStats)
#print("\nMean of Records collected per month")
#print(noOfRecordsPerMonth.mean())
#print("\nMean Mbps Per Month")
#print(dfDubai)


#mask = (df['birth_date'] > start_date) & (df['birth_date'] <= end_date)
dfMuscat_upload
# Out:
#             Throughput_Muscat  month  year
# date
# 2019-05-31           5.140554      5  2019
# 2019-06-30           4.216340      6  2019
# 2019-07-31           3.856932      7  2019
# 2019-08-31           4.363457      8  2019
# 2019-09-30           4.965727      9  2019
# 2019-10-31           5.890543     10  2019
# 2019-11-30           5.801583     11  2019
# 2019-12-31           6.643187     12  2019
# 2020-01-31           7.516551      1  2020
# 2020-02-29           6.559945      2  2020
# 2020-03-31           6.079426      3  2020
# 2020-04-30           7.098366      4  2020
# 2020-05-31           8.196728      5  2020
# 2020-06-30           6.584721      6  2020
# 2020-07-31           6.636142      7  2020
# 2020-08-31           7.053413      8  2020
# 2020-09-30           8.701473      9  2020
# 2020-10-31           9.045026     10  2020
# 2020-11-30           8.774146     11  2020
# 2020-12-31           9.842987     12  2020
# 2021-01-31          10.945835      1  2021
# 2021-02-28           9.985776      2  2021
# 2021-03-31          10.173595      3  2021
# 2021-04-30          11.057092      4  2021
# 2021-05-31          11.327133      5  2021
# 2021-06-30          10.925513      6  2021
# 2021-07-31          12.599068      7  2021
# 2021-08-31          11.899946      8  2021
# 2021-09-30          12.801158      9  2021
# 2021-10-31          11.455730     10  2021
# 2021-11-30           8.547316     11  2021
# 2021-12-31           9.074899     12  2021
# 2022-01-31           9.039907      1  2022
# 2022-02-28          10.092602      2  2022
# 2022-03-31          10.294811      3  2022
# 2022-04-30          10.844216      4  2022

# %% [markdown]
# ## Muscat Plot

# %%
#Muscat plot
fig, ax = plt.subplots(1,2)
sb.lineplot(x='month',y='Throughput_Muscat',data=dfMuscat, hue = 'year', 
            style='year', markers=True, palette=palette, size='year', 
            legend=False, ax = ax[0]) # for download

sb.lineplot(x='month',y='Throughput_Muscat',data=dfMuscat_upload, hue = 'year', 
            style='year', markers=True, palette=palette, size='year', 
            legend=False, ax = ax[1]) # for upload

ax[0].tick_params(axis = 'both', which = 'major', labelsize = 15)
ax[0].set_xlabel('Months of the Year', fontdict={'fontsize': 14}, labelpad = 15)
ax[0].set_ylabel('Throughput (Mbps)', fontdict={'fontsize': 14}, labelpad = 15)
ax[0].set_title('Download', fontdict={'fontsize': 20})

ax[1].tick_params(axis = 'both', which = 'major', labelsize = 15)
ax[1].set_xlabel('Months of the Year', fontdict={'fontsize': 14}, labelpad = 15)
ax[1].set_ylabel('Throughput (Mbps)', fontdict={'fontsize': 14}, labelpad = 15)
ax[1].set_title('Upload', fontdict={'fontsize': 20})
ax[1].yaxis.tick_right()
ax[1].yaxis.set_label_position('right')

plt.margins(0.03)
ax[0].legend(labels=['2019','2020', '2021', '2022'], prop={'size': 14}, bbox_to_anchor=(1.2, 1.3))
plt.savefig('figures/muscatthru.pdf', bbox_inches='tight')

# %% [markdown]
# ## Manama - Download

# %%
#Manama - Import Data
df = pd.read_csv(r'manama\manama_download_may22.csv', parse_dates=['date'], index_col='date')

#mainStats = df.describe()
#noOfRecordsPerMonth = df.groupby(pd.Grouper(freq='M'))['MeanThroughputMbps'].count() # Number of records collected for each month
dfManama = df.resample('M').agg({'MeanThroughputMbps':'mean'}).rename(columns={"MeanThroughputMbps":"Throughput_Manama"})
dfManama['month'] = pd.to_datetime(dfManama.index).month
dfManama['year'] = pd.to_datetime(dfManama.index).year
#print("Number of Records per Month")
#print(noOfRecordsPerMonth)
#print("\nMain Statistics")
#print(mainStats)
#print("\nMean of Records collected per month")
#print(noOfRecordsPerMonth.mean())
#print("\nMean Mbps Per Month")
#print(dfDubai)


#mask = (df['birth_date'] > start_date) & (df['birth_date'] <= end_date)
dfManama
# Out:
#             Throughput_Manama  month  year
# date
# 2019-05-31           5.752473      5  2019
# 2019-06-30           7.925939      6  2019
# 2019-07-31           5.372652      7  2019
# 2019-08-31           6.519010      8  2019
# 2019-09-30           7.527802      9  2019
# 2019-10-31           7.328355     10  2019
# 2019-11-30           9.326349     11  2019
# 2019-12-31           9.517627     12  2019
# 2020-01-31          10.558622      1  2020
# 2020-02-29          10.475500      2  2020
# 2020-03-31          10.004757      3  2020
# 2020-04-30          13.753242      4  2020
# 2020-05-31          13.885625      5  2020
# 2020-06-30          17.251563      6  2020
# 2020-07-31          17.027328      7  2020
# 2020-08-31          15.633452      8  2020
# 2020-09-30          17.108635      9  2020
# 2020-10-31          13.143068     10  2020
# 2020-11-30          11.790779     11  2020
# 2020-12-31          17.301291     12  2020
# 2021-01-31          19.107350      1  2021
# 2021-02-28          18.452484      2  2021
# 2021-03-31          15.431924      3  2021
# 2021-04-30          14.572693      4  2021
# 2021-05-31          15.339016      5  2021
# 2021-06-30          14.325232      6  2021
# 2021-07-31          13.747335      7  2021
# 2021-08-31          20.583909      8  2021
# 2021-09-30          19.946726      9  2021
# 2021-10-31          17.055460     10  2021
# 2021-11-30          11.591203     11  2021
# 2021-12-31          26.692276     12  2021
# 2022-01-31          17.427500      1  2022
# 2022-02-28          13.085016      2  2022
# 2022-03-31          13.648024      3  2022
# 2022-04-30          11.449790      4  2022

# %% [markdown]
# ## Manama - Upload

# %%
df = pd.read_csv(r'manama\manama_upload_may22.csv', parse_dates=['date'], index_col='date')

#mainStats = df.describe()
#noOfRecordsPerMonth = df.groupby(pd.Grouper(freq='M'))['MeanThroughputMbps'].count() # Number of records collected for each month
dfManama_upload = df.resample('M').agg({'MeanThroughputMbps':'mean'}).rename(columns={"MeanThroughputMbps":"Throughput_Manama"})
dfManama_upload['month'] = pd.to_datetime(dfManama_upload.index).month
dfManama_upload['year'] = pd.to_datetime(dfManama_upload.index).year
#print("Number of Records per Month")
#print(noOfRecordsPerMonth)
#print("\nMain Statistics")
#print(mainStats)
#print("\nMean of Records collected per month")
#print(noOfRecordsPerMonth.mean())
#print("\nMean Mbps Per Month")
#print(dfDubai)


#mask = (df['birth_date'] > start_date) & (df['birth_date'] <= end_date)
dfManama_upload
# Out:
#             Throughput_Manama  month  year
# date
# 2019-05-31           2.961030      5  2019
# 2019-06-30           3.147807      6  2019
# 2019-07-31           2.805128      7  2019
# 2019-08-31           2.267996      8  2019
# 2019-09-30           3.052284      9  2019
# 2019-10-31           2.957434     10  2019
# 2019-11-30           4.303510     11  2019
# 2019-12-31           5.258025     12  2019
# 2020-01-31           4.497216      1  2020
# 2020-02-29           4.434152      2  2020
# 2020-03-31           5.728778      3  2020
# 2020-04-30           6.825089      4  2020
# 2020-05-31           7.848315      5  2020
# 2020-06-30           7.490706      6  2020
# 2020-07-31           8.537524      7  2020
# 2020-08-31          13.427289      8  2020
# 2020-09-30          15.129538      9  2020
# 2020-10-31          13.446320     10  2020
# 2020-11-30          11.144695     11  2020
# 2020-12-31          14.148435     12  2020
# 2021-01-31           8.144182      1  2021
# 2021-02-28          14.212059      2  2021
# 2021-03-31          17.257279      3  2021
# 2021-04-30          17.850196      4  2021
# 2021-05-31          14.521411      5  2021
# 2021-06-30          19.037234      6  2021
# 2021-07-31          22.728202      7  2021
# 2021-08-31          26.928854      8  2021
# 2021-09-30          20.238367      9  2021
# 2021-10-31          30.508997     10  2021
# 2021-11-30          29.372958     11  2021
# 2021-12-31          19.682732     12  2021
# 2022-01-31          14.400613      1  2022
# 2022-02-28          15.140023      2  2022
# 2022-03-31          12.094882      3  2022
# 2022-04-30          14.202848      4  2022

# %% [markdown]
# ## Manama Plot

# %%
#Manama plot
fig, ax = plt.subplots(1,2)
sb.lineplot(x='month',y='Throughput_Manama',data=dfManama, hue = 'year', 
            style='year', markers=True, palette=palette, size='year', 
            legend=False, ax = ax[0]) # for download

sb.lineplot(x='month',y='Throughput_Manama',data=dfManama_upload, hue = 'year', 
            style='year', markers=True, palette=palette, size='year', 
            legend=False, ax = ax[1]) # for upload

ax[0].tick_params(axis = 'both', which = 'major', labelsize = 15)
ax[0].set_xlabel('Months of the Year', fontdict={'fontsize': 14}, labelpad = 15)
ax[0].set_ylabel('Throughput (Mbps)', fontdict={'fontsize': 14}, labelpad = 15)
ax[0].set_title('Download', fontdict={'fontsize': 20})

ax[1].tick_params(axis = 'both', which = 'major', labelsize = 15)
ax[1].set_xlabel('Months of the Year', fontdict={'fontsize': 14}, labelpad = 15)
ax[1].set_ylabel('Throughput (Mbps)', fontdict={'fontsize': 14}, labelpad = 15)
ax[1].set_title('Upload', fontdict={'fontsize': 20})
ax[1].yaxis.tick_right()
ax[1].yaxis.set_label_position('right')

plt.margins(0.03)
ax[0].legend(labels=['2019','2020', '2021', '2022'], prop={'size': 14}, bbox_to_anchor=(1.2, 1.3))
plt.savefig('figures/manamathru.pdf', bbox_inches='tight')

# %% [markdown]
# ## Download - All

# %%
#resample for quarters
dfRiyadh_T = dfRiyadh.resample('Q').agg({'Throughput_Riyadh':'mean'})
dfDubai_T = dfDubai.resample('Q').agg({'Throughput_Dubai':'mean'})
dfMuscat_T = dfMuscat.resample('Q').agg({'Throughput_Muscat':'mean'})
dfKuwait_T = dfKuwait.resample('Q').agg({'Throughput_Kuwait':'mean'})
dfDoha_T = dfDoha.resample('Q').agg({'Throughput_Doha':'mean'})
dfManama_T = dfManama.resample('Q').agg({'Throughput_Manama':'mean'})

# %% [markdown]
# ## Plot All

# %%
fig = plt.figure(figsize=(10,6))
sb.lineplot(x = dfRiyadh_T.index, y = 'Throughput_Riyadh', data = dfRiyadh_T, markers=True, marker = 'D')
sb.lineplot(x = dfDubai_T.index, y = 'Throughput_Dubai', data = dfDubai_T, markers=True, marker = 'P', linestyle = "-")
sb.lineplot(x = dfMuscat_T.index, y = 'Throughput_Muscat', data = dfMuscat_T, markers=True, marker = 'X')
sb.lineplot(x = dfKuwait_T.index, y = 'Throughput_Kuwait', data = dfKuwait_T, markers=True, marker = 's', linestyle = "-.")
sb.lineplot(x = dfDoha_T.index, y = 'Throughput_Doha', data = dfDoha_T, markers=True, marker = 'd', linestyle = ":")
sb.lineplot(x = dfManama_T.index, y = 'Throughput_Manama', data = dfManama_T, markers=True, linestyle = "--")

plt.margins(0.05)
fig.legend(labels=['Riyadh','Dubai','Muscat', 'Kuwait', 'Doha', 'Manama'], prop={'size': 14}, bbox_to_anchor=(1.05, 0.9))
plt.xticks(rotation = 90, fontsize = 16)
plt.yticks(fontsize = 16)
plt.ylabel("Throughput", fontdict={'fontsize': 16}, labelpad = 15)
plt.xlabel("Date Range: May 2019 to April 2022", fontdict={'fontsize': 16}, labelpad = 15)
#plt.title("Monthly Throughput Patterns for Major Cities in the GCC", fontdict={'fontsize': 20})
plt.savefig('figures/all_thru.pdf', bbox_inches='tight')

# %% [markdown]
# ## Uplaod - All

# %%
#resample for quarters
dfRiyadh_T = dfRiyadh_upload.resample('Q').agg({'Throughput_Riyadh':'mean'})
dfDubai_T = dfDubai_upload.resample('Q').agg({'Throughput_Dubai':'mean'})
dfMuscat_T = dfMuscat_upload.resample('Q').agg({'Throughput_Muscat':'mean'})
dfKuwait_T = dfKuwait_upload.resample('Q').agg({'Throughput_Kuwait':'mean'})
dfDoha_T = dfDoha_upload.resample('Q').agg({'Throughput_Doha':'mean'})
dfManama_T = dfManama_upload.resample('Q').agg({'Throughput_Manama':'mean'})

# %%
sb.set(style="whitegrid")                                                 
paper_rc = {'lines.linewidth': 2, 'lines.markersize': 8}                  
sb.set_context("paper", rc = paper_rc)    
sb.set_palette("colorblind")

fig = plt.figure(figsize=(10,6))
sb.lineplot(x = dfRiyadh_T.index, y = 'Throughput_Riyadh', data = dfRiyadh_T, markers=True, marker = 'D')
sb.lineplot(x = dfDubai_T.index, y = 'Throughput_Dubai', data = dfDubai_T, markers=True, marker = 'P', linestyle = "-")
sb.lineplot(x = dfMuscat_T.index, y = 'Throughput_Muscat', data = dfMuscat_T, markers=True, marker = 'X')
sb.lineplot(x = dfKuwait_T.index, y = 'Throughput_Kuwait', data = dfKuwait_T, markers=True, marker = 's', linestyle = "-.")
sb.lineplot(x = dfDoha_T.index, y = 'Throughput_Doha', data = dfDoha_T, markers=True, marker = 'd', linestyle = ":")
sb.lineplot(x = dfManama_T.index, y = 'Throughput_Manama', data = dfManama_T, markers=True, linestyle = "--")

plt.margins(0.05)
fig.legend(labels=['Riyadh','Dubai','Muscat', 'Kuwait', 'Doha', 'Manama'], prop={'size': 14}, bbox_to_anchor=(1.05, 0.9))
plt.xticks(rotation = 90, fontsize = 16)
plt.yticks(fontsize = 16)
plt.ylabel("Throughput", fontdict={'fontsize': 16}, labelpad = 15)
plt.xlabel("Date Range: May 2019 to April 2022", fontdict={'fontsize': 16}, labelpad = 15)
#plt.title("Monthly Throughput Patterns for Major Cities in the GCC", fontdict={'fontsize': 20})
plt.savefig('figures/all_thru_upload.pdf', bbox_inches='tight')
